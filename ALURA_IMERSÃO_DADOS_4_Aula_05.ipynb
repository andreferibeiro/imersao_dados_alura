# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

pd.set_option("display.precision", 2)
pd.set_option('display.float_format', lambda x: '%.2f' % x)
sns.set()

dados_vendas_censo = pd.read_csv("/content/drive/MyDrive/dados_vendas_censo.csv")
dados_vendas_censo = dados_vendas_censo[['Rua', 'Bairro', 'Cidade', 'Metragem', 'Quartos', 'Banheiros', 'Vagas',
       'Valor_anuncio', 'Valor_mm', 'Valor_m2', 'latitude', 'longitude', 'Situacao_setor', 'V001',
       'V002', 'V003', 'V004', 'V005', 'V006', 'V007', 'V008', 'V009', 'V010',
       'V011', 'V012']].dropna()
dados_vendas_censo
# Out:
#                                  Rua              Bairro      Cidade  \
# 0              Avenida Itacira, 255    Planalto Paulista  SÃ£o Paulo
# 1     Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  SÃ£o Paulo
# 2                    Rua Alba Valdez     Jardim Reimberg  SÃ£o Paulo
# 3           Rua Tobias Barreto, 195                Mooca  SÃ£o Paulo
# 4                    Rua Graham Bell         Santo Amaro  SÃ£o Paulo
# ...                              ...                 ...         ...
# 5599              Rua Pedro Teixeira       Vila OlÃ­mpia  SÃ£o Paulo
# 5600                   Avenida Odila   Planalto Paulista  SÃ£o Paulo
# 5601                     Rua TapuÃ§u          Vila Sofia  SÃ£o Paulo
# 5603               Rua Estero Belaco      Vila da SaÃºde  SÃ£o Paulo
# 5604    Rua BarÃ£o de TramandaÃ­, 0          Vila Alpina  SÃ£o Paulo
#
#       Metragem  Quartos  Banheiros  Vagas  Valor_anuncio  Valor_mm  Valor_m2  \
# ...

# %%
dados_vendas_censo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5308 entries, 0 to 5604
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Rua             5308 non-null   object
#  1   Bairro          5308 non-null   object
#  2   Cidade          5308 non-null   object
#  3   Metragem        5308 non-null   int64
#  4   Quartos         5308 non-null   int64
#  5   Banheiros       5308 non-null   int64
#  6   Vagas           5308 non-null   int64
#  7   Valor_anuncio   5308 non-null   int64
#  8   Valor_mm        5308 non-null   float64
#  9   Valor_m2        5308 non-null   float64
#  10  latitude        5308 non-null   float64
#  11  longitude       5308 non-null   float64
#  12  Situacao_setor  5308 non-null   float64
#  13  V001            5308 non-null   float64
#  14  V002            5308 non-null   float64
#  15  V003            5308 non-null   float64
#  16  V004            5308 non-null   float64
# ...

# %%
plt.figure(figsize=(10, 8))
ax = sns.boxplot(data = dados_vendas_censo, y="Valor_anuncio")
plt.show()

# %%
dados_vendas_censo.query("Valor_anuncio > 30000000 | Valor_anuncio < 100000")
# Out:
#                         Rua           Bairro      Cidade  Metragem  Quartos  \
# 54           Rua Inglaterra    Jardim Europa  SÃ£o Paulo       200        3
# 89           Rua Inglaterra    Jardim Europa  SÃ£o Paulo       756        5
# 1032  PraÃ§a Nicolau Scarpa  Jardim AmÃ©rica  SÃ£o Paulo      1200        4
# 3521     Rua Estados Unidos  Jardim AmÃ©rica  SÃ£o Paulo      1816        4
# 3896     Rua Estados Unidos  Jardim AmÃ©rica  SÃ£o Paulo      1200        4
#
#       Banheiros  Vagas  Valor_anuncio  Valor_mm  Valor_m2  ...  V003  V004  \
# 54            3      2          13000      0.01     65.00  ...  3.13  2.87
# 89            4     10       37000000     37.00  48941.80  ...  3.13  2.87
# 1032          4     25       65000000     65.00  54166.67  ...  3.57  3.01
# 3521         10     20       55000000     55.00  30286.34  ...  3.57  3.01
# 3896          6     24       65000000     65.00  54166.67  ...  3.57  3.01
#
# ...

# %%
dados_vendas_censo.drop(dados_vendas_censo.query("Valor_anuncio > 30000000 | Valor_anuncio < 100000").index, inplace = True)
plt.figure(figsize=(10, 8))
ax = sns.boxplot(data = dados_vendas_censo, y="Valor_anuncio")
plt.show()

# %%
plt.figure(figsize=(10, 10))
sns.scatterplot(data = dados_vendas_censo, x="Valor_anuncio", y="Valor_m2")

# %%
dados_vendas_censo.corr()
# Out:
#                 Metragem  Quartos  Banheiros  Vagas  Valor_anuncio  Valor_mm  \
# Metragem            1.00     0.23       0.23   0.27           0.30      0.30
# Quartos             0.23     1.00       0.55   0.42           0.37      0.37
# Banheiros           0.23     0.55       1.00   0.46           0.47      0.47
# Vagas               0.27     0.42       0.46   1.00           0.48      0.48
# Valor_anuncio       0.30     0.37       0.47   0.48           1.00      1.00
# Valor_mm            0.30     0.37       0.47   0.48           1.00      1.00
# Valor_m2            0.06     0.12       0.22   0.15           0.70      0.70
# latitude           -0.09    -0.01      -0.03  -0.04           0.02      0.02
# longitude          -0.13    -0.19      -0.25  -0.19          -0.21     -0.21
# Situacao_setor      0.48    -0.01      -0.03  -0.01          -0.00     -0.00
# V001               -0.13    -0.18      -0.22  -0.21          -0.22     -0.22
# ...

# %%
plt.figure(figsize=(18, 8))
#https://www.tylervigen.com/spurious-correlations
mask = np.triu(np.ones_like(dados_vendas_censo.corr(), dtype=bool))
heatmap = sns.heatmap(dados_vendas_censo.corr(method='pearson'), mask=mask, vmin=-1, vmax=1, annot=True, cmap='coolwarm')
heatmap.set_title('Correlação entre as Variáveis Numéricas', fontdict={'fontsize':18}, pad=16);

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

X = dados_vendas_censo[["Metragem"]]
Y = dados_vendas_censo["Valor_anuncio"]

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.25, random_state = 54)
lr = LinearRegression()

# %%
X_train
# Out:
#       Metragem
# 3522       105
# 881        240
# 769        324
# 3364       484
# 4674       103
# ...        ...
# 3558       397
# 3994       224
# 5432       238
# 4044       300
# 948        186
#
# [3977 rows x 1 columns]

# %%
lr.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_predict_test = lr.predict(X_test)
Y_predict_test
# Out:
# array([4535135.54576314, 2319529.74583429, 2424501.59358835, ...,
#        2802400.24550293, 2483285.82833061, 2854186.3570616 ])

# %%
Y_test
# Out:
# 172     4500000
# 4513     345000
# 4865     800000
# 4979    4000000
# 1255    5100000
#          ...
# 5240    1600000
# 4472     580000
# 3291    2200000
# 432     1500000
# 2455    2800000
# Name: Valor_anuncio, Length: 1326, dtype: int64

# %%
Y_predict_train = lr.predict(X_train)

# %%
Y_train
# Out:
# 3522     692000
# 881     1490000
# 769     2100000
# 3364    6700000
# 4674     622500
#          ...
# 3558    4280000
# 3994    1500000
# 5432    2300000
# 4044    1600000
# 948     3280000
# Name: Valor_anuncio, Length: 3977, dtype: int64

# %%
from sklearn.metrics import mean_absolute_error, r2_score


mean_absolute_error(Y_test, Y_predict_test)
# Out:
# 1770626.9062636306

# %%
mean_absolute_error(Y_train, Y_predict_train)
# Out:
# 1825220.3034549057

# %%
X = dados_vendas_censo[['Metragem', 'Quartos', 'Banheiros', 'Vagas','V001','V007', 'V009']]

Y = dados_vendas_censo["Valor_anuncio"]

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.25, random_state = 54)
lr.fit(X_train, Y_train)
Y_predict_test = lr.predict(X_test)
Y_predict_train = lr.predict(X_train)
mae_test = mean_absolute_error(Y_test, Y_predict_test)
r2_test = r2_score(Y_test, Y_predict_test)
mae_train = mean_absolute_error(Y_train, Y_predict_train)
r2_train = r2_score(Y_train, Y_predict_train)

# %%
mae_test
# Out:
# 1349590.384432537

# %%
r2_test
# Out:
# 0.37745069254620534

# %%
mae_train
# Out:
# 1362945.691504754

# %%
r2_train
# Out:
# 0.39899592785823335

# %%
mae_test
# Out:
# 1349590.384432537

# %%
r2_test
# Out:
# 0.37745069254620534

# %%
plt.figure(figsize=(10, 10))

sns.set_theme(context='notebook', style='darkgrid', palette="Set2", font='sans-serif', font_scale=1)

ax = sns.regplot(x=Y_test, y=Y_predict_test)

plt.xticks()
ax.xaxis.set_major_formatter(million_formatter)
ax.yaxis.set_major_formatter(million_formatter)

ax.set_xlabel("Valor do Imóvel em R$")
ax.set_ylabel("Valor previsto do Valor do Imóvel em R$")
ax.set_title("Modelo de Regressão Linear Dados Cruzados")
plt.xlim(0, 30200000)
# Out:
# (0.0, 30200000.0)

# %%
plt.figure(figsize=(10, 10))
sns.scatterplot(x=Y_test, y=Y_predict_test)

# %% [markdown]
# #Desafio Aula 5
#
# 1 - Adicionar o valor "real" do m2 do imóvel.

# %% [markdown]
# 2 - Testar outro modelos de regressão.

# %%
from sklearn.linear_model import Ridge

X = dados_vendas_censo[['Metragem', 'Quartos', 'Banheiros', 'Vagas']]

Y = dados_vendas_censo["Valor_anuncio"]

X_rid_train, X_rid_test, Y_rid_train, Y_rid_test = train_test_split(X, Y, test_size = 0.3, random_state = 54)
clf = Ridge(alpha=1.0)
clf.fit(X_rid_train, Y_rid_train)
Y_rid_predict_test = lr.predict(X_rid_test)
Y_rid_predict_train = lr.predict(X_rid_train)
mae_rid_test = mean_absolute_error(Y_rid_test, Y_rid_predict_test)
r2_rid_test = r2_score(Y_rid_test, Y_rid_predict_test)
mae_rid_train = mean_absolute_error(Y_rid_train, Y_rid_predict_train)
r2_rid_train = r2_score(Y_rid_train, Y_rid_predict_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names seen at fit time, yet now missing:
# - V001
# - V007
# - V009
#
#   warnings.warn(message, FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-009cec2959de> in <module>()
#       8 clf = Ridge(alpha=1.0)
#       9 clf.fit(X_rid_train, Y_rid_train)
# ---> 10 Y_rid_predict_test = lr.predict(X_rid_test)
#      11 Y_rid_predict_train = lr.predict(X_rid_train)
#      12 mae_rid_test = mean_absolute_error(Y_rid_test, Y_rid_predict_test)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     360             Returns predicted values.
#     361         """
# --> 362         return self._decision_function(X)
# ...

# %%
mae_rid_test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-6380f0c80d14> in <module>()
# ----> 1 mae_rid_test
#
# NameError: name 'mae_rid_test' is not defined

# %%
r2_rid_test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-31309e60294e> in <module>()
# ----> 1 r2_rid_test
#
# NameError: name 'r2_rid_test' is not defined

# %%
mae_rid_train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-8ef58cb4aa35> in <module>()
# ----> 1 mae_rid_train
#
# NameError: name 'mae_rid_train' is not defined

# %%
r2_rid_train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-377e595a1040> in <module>()
# ----> 1 r2_rid_train
#
# NameError: name 'r2_rid_train' is not defined

# %% [markdown]
# 3 - Criar um modelo baseline com as features originais.

# %%
X = dados_vendas_censo[['Metragem', 'Quartos', 'Banheiros', 'Vagas']]

Y = dados_vendas_censo["Valor_anuncio"]

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3, random_state = 54)
lr.fit(X_train, Y_train)
Y_predict_test = lr.predict(X_test)
Y_predict_train = lr.predict(X_train)
mae_test = mean_absolute_error(Y_test, Y_predict_test)
r2_test = r2_score(Y_test, Y_predict_test)
mae_train = mean_absolute_error(Y_train, Y_predict_train)
r2_train = r2_score(Y_train, Y_predict_train)

# %%
mae_test
# Out:
# 1513563.4392542548

# %%
r2_test
# Out:
# 0.32199125887857016

# %%
mae_train

# %%
r2_train

# %%
plt.figure(figsize=(10, 10))
sns.regplot(x=Y_rid_test, y=Y_rid_predict_test, color="darkorange")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-c3cf27ecffe0> in <module>()
#       1 plt.figure(figsize=(10, 10))
# ----> 2 sns.regplot(x=Y_rid_test, y=Y_rid_predict_test, color="darkorange")
#
# NameError: name 'Y_rid_predict_test' is not defined

# %%
import matplotlib.ticker as ticker
@ticker.FuncFormatter
def million_formatter(x, pos):
    return "%.f mi" % (x/1E6)

# %%
plt.figure(figsize=(10, 10))

sns.set_theme(context='notebook', style='darkgrid', palette="rainbow", font='sans-serif', font_scale=1)

ax = sns.regplot(x=Y_test, y=Y_predict_test)

plt.xticks()
ax.xaxis.set_major_formatter(million_formatter)
ax.yaxis.set_major_formatter(million_formatter)

ax.set_xlabel("Valor do Imóvel em R$")
ax.set_ylabel("Valor previsto do Valor do Imóvel em R$")
ax.set_title("Modelo de Regressão Linear Baseline")
plt.xlim(0, 30200000)
# Out:
# (0.0, 30200000.0)

# %% [markdown]
# 4 - Trabalhar um pouco mais nos dados e criar novas variáveis.

# %% [markdown]
# 5 - Testar as predições para casos reais.

# %% [markdown]
# 6 - Criar um projeto com os resultados da imersão. Postar nas redes sociais mostrando o trabalho realizado.
